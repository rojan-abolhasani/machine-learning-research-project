# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = 'Dataset_Strategies.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Response  \
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...
#
#                              Strategy
# 0                     Gestalt Therapy
# 1  Cognitive Behavioral Therapy (CBT)
# 2  Cognitive Behavioral Therapy (CBT)
# 3               Psychodynamic Therapy
# 4               Psychodynamic Therapy

# %%
print(df['Strategy'].unique())
# Out:
# ['Gestalt Therapy' 'Cognitive Behavioral Therapy (CBT)'
#  'Psychodynamic Therapy' 'Existential Therapy' 'Behavioral Therapy'
#  'Humanistic Therapy' 'Uncategorized']

# %%
print(df['Context'].nunique())
print(df.shape)
# Out:
# 995
# (3512, 3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_clean = df.dropna(subset=['Strategy'])
df_clean = df_clean[df_clean['Strategy'] != 'Uncategorized']

strategy_counts = df_clean['Strategy'].value_counts()


fig, ax = plt.subplots(figsize=(3, 3))

wedges, _ = ax.pie(strategy_counts, labels=None, startangle=140, colors=colors[:len(strategy_counts)])
ax.set_title("Proportion of Strategies", fontsize=8)

fig.legend(strategy_counts.index, title="Strategies", loc="center left", bbox_to_anchor=(1, 0.5), fontsize=6, title_fontsize=7)

plt.tight_layout()
plt.show()

# %%
total_rows = len(data)
print(f"Total number of rows: {total_rows}")

data['Context'] = data['Context'].fillna("").astype(str)
context_counts = data['Context'].value_counts()

total_unique_contexts = len(context_counts)
print(f"Total number of unique contexts: {total_unique_contexts}\n")

max_context = context_counts.idxmax()
max_count = context_counts.max()
min_context = context_counts.idxmin()
min_count = context_counts.min()

print(f"The most frequent context appears {max_count} times:")
print(max_context)
print("\n")

print(f"The least frequent context appears {min_count} times:")
print(min_context)
print("\n")

average_count = context_counts.mean()
print(f"Average count of occurrences per context: {average_count:.2f}")
# Out:
# Total number of rows: 3512
# Total number of unique contexts: 995
#
# The most frequent context appears 94 times:
# I have so many issues to address. I have a history of sexual abuse, I’m a breast cancer survivor and I am a lifetime insomniac.    I have a long history of depression and I’m beginning to have anxiety. I have low self esteem but I’ve been happily married for almost 35 years.
#    I’ve never had counseling about any of this. Do I have too many issues to address in counseling?
#
#
# The least frequent context appears 1 times:
# ...

# %%
plt.figure(figsize=(10, 6))
frequency_of_counts = context_counts.value_counts().sort_index()
frequency_of_counts.plot(kind='bar', color='orange', edgecolor='black')

plt.title('Frequency of Context Occurrence Counts', fontsize=16)
plt.xlabel('Number of Responses per Context', fontsize=14)
plt.ylabel('Number of Contexts', fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.tight_layout()

plt.show()

# %%
max_context_length = data['Context'].str.len().max()
min_context_length = data['Context'].str.len().min()

max_response_length = data['Response'].str.len().max()
min_response_length = data['Response'].str.len().min()

# Print results
print(f"Maximum Context Length: {max_context_length} characters")
print(f"Minimum Context Length: {min_context_length} characters")
print(f"Maximum Response Length: {max_response_length} characters")
print(f"Minimum Response Length: {min_response_length} characters")
# Out:
# Maximum Context Length: 2703 characters
# Minimum Context Length: 25 characters
# Maximum Response Length: 32739 characters
# Minimum Response Length: 1 characters

# %%
strategy_counts = data['Strategy'].value_counts()

max_strategy = strategy_counts.idxmax()
max_strategy_count = strategy_counts.max()

min_strategy = strategy_counts.idxmin()
min_strategy_count = strategy_counts.min()

print("Strategy Occurrences:")
print(strategy_counts)
print("\n")

print(f"The most frequent strategy is '{max_strategy}', which appears {max_strategy_count} times.")
print(f"The least frequent strategy is '{min_strategy}', which appears {min_strategy_count} times.")
# Out:
# Strategy Occurrences:
# Strategy
# Cognitive Behavioral Therapy (CBT)    884
# Psychodynamic Therapy                 590
# Humanistic Therapy                    539
# Behavioral Therapy                    527
# Existential Therapy                   496
# Gestalt Therapy                       472
# Uncategorized                           4
# Name: count, dtype: int64
#
#
# The most frequent strategy is 'Cognitive Behavioral Therapy (CBT)', which appears 884 times.
# The least frequent strategy is 'Uncategorized', which appears 4 times.

# %%
plt.figure(figsize=(10, 6))
strategy_counts.plot(kind='bar', color='lightgreen', edgecolor='black')

plt.title('Occurrences of Each Strategy', fontsize=16)
plt.xlabel('Strategy', fontsize=14)
plt.ylabel('Number of Occurrences', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.tight_layout()

plt.show()
